# %% [markdown]
# ### 지도학습
# - 입력과 결과를 주는 학습 방식
# - 주어진 입력데이터의 패턴과 그에대한 결과를 학습
# - 모든 알고리즘은 결과를 예측한다는 공통의 목표를 가지고 있다.
# - 알고리즘에 따라 학습 방식과 예측 방식이 다르다.
# - 알고리즘 마다 성능이 다르고 속도가 다르다.

# %% [markdown]
# ### 비 지도 학습
# - 입력 데이터만 주어진다.
# - 알고리즘 마다 지향하는 목표가 다르다.
# - 각 알고리즘이 무엇을 할 수 있는지 학습하는 것이 매우 중요하다.
