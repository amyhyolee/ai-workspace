# %%
# numpy
# 파이썬에서 대용량 행렬데이터를 처리하기 위한 라이브러리
# !pip install numpy

# %%
# pandas
# 데이터 분석, 정제 등등 다양한 작업을 할 수 있는 데이터 분석용 라이브러리
# !pip install pandas

# %%
# requests
# 웹 사이트에 요청할 수 있는 라이브러리
# !pip install requests

# %%
# bs4
# 사이트 데이터 분석 수집 라이브러리
# !pip install bs4

# %%
# xml, html 문서를 분석(parsing)하는 라이브러리
# !pip install lxml

# %%
# selenium
# 웹 브라우저를 제어할 수 있는 라이브러리
# !pip install selenium
# Out:
# ...
#      |████████████████████████████████| 958 kB 5.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 356 kB 13.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 58 kB 12.3 MB/s eta 0:00:01
# ...

# %%
# RSS 문서 분석 라이브러리
# !pip install feedparser
# Out:
# ...
#      |████████████████████████████████| 81 kB 4.3 MB/s eta 0:00:011
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6065 sha256=9425bdabc92158797df7abf80e245abb01f57d6bcfb95e377254984dc29b7d7c
#   Stored in directory: /Users/hyojinlee/Library/Caches/pip/wheels/65/7a/a7/78c287f64e401255dff4c13fdbc672fed5efbfd21c530114e1
# Successfully built sgmllib3k
# ...

# %%
# openpyxl
# 판다스를 이용해 엑셀파일을 읽어들일 때 필요하다.
# !pip install openpyxl

# %%
# 시각화 라이브러리
# !pip install matplotlib

# %%
# 과학 산술 연산용 라이브러리
# !pip install scipy

# %%
# 시각화 라이브러리
# !pip install seaborn

# %%
# 시각화 라이브러리
# !pip install plotly
# Out:
# ...
#      |████████████████████████████████| 27.7 MB 9.4 MB/s eta 0:00:011
# ...

# %%
# 데이터를 읽어들일 수 있는 라이브러리
# !pip install pandas_datareader
# Out:
# ...
#      |████████████████████████████████| 109 kB 5.0 MB/s eta 0:00:01
# ...

# %%
# opencv 설치
# opencv 는 원래 설치과정이 복잡하다. 하지만 설치방법이 변경되어
# 매우 간단하다.
# !pip install opencv-python
# Out:
# ...
#      |████████████████████████████████| 46.0 MB 9.0 MB/s eta 0:00:011
# ...

# %%
# 머신러닝 라이브러리
# !pip install sklearn
# Out:
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=6da170a213a987bf5e38fa3183cba0d9a82b3e243f578f13ccd59be2af7d63cd
#   Stored in directory: /Users/hyojinlee/Library/Caches/pip/wheels/e4/7b/98/b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built sklearn
# ...

# %%
# 부스팅 라이브러리
# !pip install lightgbm

# %%
# 부스팅 라이브러리
# !pip install xgboost
# Out:
# ...
#   Using cached xgboost-1.5.2-py3-none-macosx_10_15_x86_64.macosx_11_0_x86_64.macosx_12_0_x86_64.whl (1.3 MB)
# ...

# %%
# 상관관계 분석
# !pip install patsy

# %%
# 상관관계 분석
# !pip install statsmodels

# %%
# 형태소 분석기
# !pip install soynlp
# Out:
# ...
#      |████████████████████████████████| 416 kB 4.8 MB/s eta 0:00:01
# ...

# %%
# 워드 클라우드
# !pip install pytagcloud
# !pip install pygame
# !pip install simplejson
# Out:
# ...
#      |████████████████████████████████| 754 kB 5.3 MB/s eta 0:00:01
# ...
#   Created wheel for pytagcloud: filename=pytagcloud-0.3.5-py3-none-any.whl size=759870 sha256=07b6de7b5bb483e50e8c5255050d2f673437c009de78c8c3c2566d88b9783381
#   Stored in directory: /Users/hyojinlee/Library/Caches/pip/wheels/74/9f/93/6322d7ac8b7c348b7d625f95919691d20cd46d2989dc61b165
# Successfully built pytagcloud
# ...
#      |████████████████████████████████| 8.9 MB 4.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 74 kB 4.3 MB/s eta 0:00:011
# ...

# %%
# 시계열 분석을 위한 arima
# !pip install pmdarima
# Out:
# ...
#      |████████████████████████████████| 604 kB 5.1 MB/s eta 0:00:01
# ...

# %%
# 추천 알고리즘
# !pip install surprise
# Out:
# ...
#      |████████████████████████████████| 11.8 MB 453 kB/s eta 0:00:01
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.1-cp39-cp39-macosx_10_9_x86_64.whl size=749274 sha256=9225cf7e467524b006c0e6857b6c78b79c1e3981c0f8a571473e5b9ffcdd2631
#   Stored in directory: /Users/hyojinlee/Library/Caches/pip/wheels/6b/10/c9/7f607c8cb522ef378844f41e63b30d7181a6495d2c1ae514e9
# Successfully built scikit-surprise
# ...

# %%
# 한국어 형태소 분석기
# !pip install konlpy
# Out:
# ...
#      |████████████████████████████████| 19.4 MB 9.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 381 kB 10.3 MB/s eta 0:00:01
# ...

# %%
#### MacOS
# !python3 -m pip install --upgrade pip
# !python3 -m pip install konlpy 

# !bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)
# Out:
# ...
# Installing automake (A dependency for mecab-ko)
# This script require Homebrew!
# Try https://brew.sh/

# %%
#### WINDOW
# JDK 설치가 필요하다.
# https://blog.naver.com/PostView.nhn?blogId=alcmskfl17&logNo=221870079271
# jdk를 설치한다.
# 탐색기에서 내 pc에서 우클릭한다.
# 속성을 클릭한다.
# 클릭후 나타나는 화면에서 시스템 고급설정을 클릭한다.
# 시스템 속성창이 뜨면 환경 변수를 눌러준다.
# 환경 변수창이 뜨면 새로만들기 버튼을 눌러준다.(아무거나)
# 변수 이름 : JAVA_HOME
# 변수 값 : jdk 설치 경로 (C:\Program Files\Java\jdk1.8.0_321)

# %%
# !pip install fbprophet
# Out:
# ...
#   Using cached fbprophet-0.7.1.tar.gz (64 kB)
# ...
#   ERROR: Command errored out with exit status 1:
#    command: /Users/hyojinlee/opt/anaconda3/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/gr/n8_lnq3n4bq1z2j7w3hrtg_40000gn/T/pip-install-md_bt1zi/fbprophet_849ee7ee6bf84f0a954a980267d514c5/setup.py'"'"'; __file__='"'"'/private/var/folders/gr/n8_lnq3n4bq1z2j7w3hrtg_40000gn/T/pip-install-md_bt1zi/fbprophet_849ee7ee6bf84f0a954a980267d514c5/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/gr/n8_lnq3n4bq1z2j7w3hrtg_40000gn/T/pip-wheel-u4wx8i5w
#        cwd: /private/var/folders/gr/n8_lnq3n4bq1z2j7w3hrtg_40000gn/T/pip-install-md_bt1zi/fbprophet_849ee7ee6bf84f0a954a980267d514c5/
# ...

# %% [markdown]
# 다운 받아야 할것
# 맥: fbprophet, konlpy
# 윈도우: fbprophet, surprise
