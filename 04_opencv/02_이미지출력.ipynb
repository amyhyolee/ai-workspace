# %% [markdown]
# ### 이미지 출력

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# opencv
import cv2

# 그래프에 대한 기본설정
# plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = 20, 10
plt.rcParams['font.size'] = 16
plt.rcParams['axes.unicode_minus'] = False

# %%
# 이미지를 불러온다.
image = cv2.imread('opencv_image/1.jpg')
image
# Out:
# array([[[2, 1, 3],
#         [2, 1, 3],
#         [2, 1, 3],
#         ...,
#         [1, 0, 2],
#         [1, 0, 2],
#         [1, 0, 2]],
#
#        [[2, 1, 3],
#         [2, 1, 3],
#         [2, 1, 3],
#         ...,
#         [1, 0, 2],
#         [1, 0, 2],
#         [1, 0, 2]],
#
#        [[1, 0, 2],
#         [1, 0, 2],
#         [1, 0, 2],
#         ...,
#         [1, 0, 2],
#         [1, 0, 2],
#         [1, 0, 2]],
#
#        ...,
#
#        [[2, 1, 3],
#         [1, 0, 2],
#         [1, 0, 2],
#         ...,
#         [1, 0, 2],
#         [1, 0, 2],
#         [1, 0, 2]],
#
#        [[1, 0, 2],
#         [1, 0, 2],
#         [1, 0, 2],
#         ...,
#         [1, 0, 2],
#         [1, 0, 2],
#         [1, 0, 2]],
#
#        [[1, 0, 2],
#         [1, 0, 2],
#         [1, 0, 2],
#         ...,
#         [1, 0, 2],
#         [0, 0, 1],
#         [1, 0, 2]]], dtype=uint8)

# %%
# 이미지를 그린다.
cv2.imshow('Moon', image)
# 코드의 흐름을 일시 정지 시켜야 한다.
cv2.waitKey()
# 이미지창을 닫아준다.
cv2.destroyAllWindows()
